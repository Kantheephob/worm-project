# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Import

# %%
import sys
sys.path.insert(0,'/project/lt200264-saiwat/Code/Segmentation') 
from showImage import showImagesFromDir

# %%
img_folder = '/scratch/lt200264-saiwat/sam3_test_01/_debug'
showImagesFromDir(img_folder,'*.png',501,600, ncols= 1)
